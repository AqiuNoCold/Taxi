# %%
import pandas as pd
df = pd.read_csv("./data/train.csv")
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %%
from utils import preprocess_copy

df_processed = preprocess_copy(df)
df_processed.keys()
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration', 'pickup_hour', 'distance_km', 'speed_kmh'],
#       dtype='object')

# %%
from utils import visualize_all
visualize_all(df_processed)

# %%
df_processed.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  pickup_hour  \
# 0         40.765602                  N            455           17
# 1         40.731152                  N            663            0
# 2         40.710087                  N           2124           11
# 3         40.706718                  N            429           19
# 4         40.782520                  N            435           13
#
#    distance_km  speed_kmh
# 0     1.498521  11.856428
# 1     1.805507   9.803659
# 2     6.385098  10.822201
# 3     1.485498  12.465721
# 4     1.188588   9.836594

# %%
from utils import feature_importance
importance, model = feature_importance(df)
print(importance)
# Out:
#              feature  importance
# 7        distance_km    0.296140
# 3    pickup_latitude    0.294778
# 2   pickup_longitude    0.132224
# 5   dropoff_latitude    0.104611
# 4  dropoff_longitude    0.084493
# 6        pickup_hour    0.072485
# 1    passenger_count    0.011550
# 0          vendor_id    0.003719

# %%
from utils import plot_importance
plot_importance(importance)
