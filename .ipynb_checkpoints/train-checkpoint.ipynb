# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
import lightgbm as lgb
from sklearn.metrics import mean_squared_log_error
from sklearn.cluster import MiniBatchKMeans
import matplotlib.pyplot as plt
from utils import preprocess_copy, calculate_bearing, haversine, dummy_manhattan_distance

# 1. 读取并预处理训练数据
df = pd.read_csv("./data/train.csv")
df = preprocess_copy(df)

df_test = pd.read_csv("./data/test.csv")
# --- 测试集预处理开始 ---
# 基础时间转换
df_test["pickup_datetime"] = pd.to_datetime(df_test["pickup_datetime"])

# 计算时间特征
df_test["month"] = df_test["pickup_datetime"].dt.month
df_test["day_of_week"] = df_test["pickup_datetime"].dt.dayofweek
df_test["pickup_hour"] = df_test["pickup_datetime"].dt.hour

# 计算地理特征
df_test["manhattan_dist"] = dummy_manhattan_distance(
    df_test["pickup_latitude"], df_test["pickup_longitude"],
    df_test["dropoff_latitude"], df_test["dropoff_longitude"]
)
df_test["distance_km"] = haversine(
    df_test["pickup_longitude"], df_test["pickup_latitude"],
    df_test["dropoff_longitude"], df_test["dropoff_latitude"]
)
df_test["direction"] = calculate_bearing(
    df_test['pickup_latitude'], df_test['pickup_longitude'],
    df_test['dropoff_latitude'], df_test['dropoff_longitude']
)
# --- 测试集预处理结束 ---

# %%
print("Generating Clustering Features...")
# 过滤
coord_cols = ['pickup_latitude', 'pickup_longitude', 'dropoff_latitude', 'dropoff_longitude']

# 从训练集提取有效的坐标
train_coords = df[coord_cols].dropna()
# 从测试集提取有效的坐标
test_coords = df_test[coord_cols].dropna()


coords = np.vstack((
    train_coords[['pickup_latitude', 'pickup_longitude']].values,
    train_coords[['dropoff_latitude', 'dropoff_longitude']].values,
    test_coords[['pickup_latitude', 'pickup_longitude']].values,
    test_coords[['dropoff_latitude', 'dropoff_longitude']].values
))
kmeans = MiniBatchKMeans(n_clusters=100, batch_size=10000, random_state=42, n_init=10).fit(coords)

def get_cluster(data, km_model):
    # 找到非 NaN 的行
    valid_mask = data.notna().all(axis=1)
    # 初始化结果数组，默认填 -1 (代表未知区域)
    clusters = np.full(len(data), -1)
    
    if valid_mask.sum() > 0:
        # 只对有效数据进行预测
        clusters[valid_mask] = km_model.predict(data.loc[valid_mask].values)
    
    return clusters

# 为训练集生成
df.loc[:, 'pickup_cluster'] = get_cluster(df[['pickup_latitude', 'pickup_longitude']], kmeans)
df.loc[:, 'dropoff_cluster'] = get_cluster(df[['dropoff_latitude', 'dropoff_longitude']], kmeans)

# 为测试集生成
df_test.loc[:, 'pickup_cluster'] = get_cluster(df_test[['pickup_latitude', 'pickup_longitude']], kmeans)
df_test.loc[:, 'dropoff_cluster'] = get_cluster(df_test[['dropoff_latitude', 'dropoff_longitude']], kmeans)

print("Clustering Features Generated.")
# Out:
# Generating Clustering Features...
# Clustering Features Generated.

# %%
# 特征列表
features = [
    'distance_km',
    'pickup_latitude', 'pickup_longitude',
    'dropoff_latitude', 'dropoff_longitude',
    'pickup_hour',
    'passenger_count',
    'vendor_id',
    'month',
    'day_of_week',
    'direction',
    'pickup_cluster',
    'dropoff_cluster',
    'manhattan_dist',
]

# %%
# 3. 准备训练数据 X 和 y
X = df[features]
y = df['trip_duration']
# 对目标变量做对数变换
y_log = np.log1p(y)

X_test = df_test[features]

# %%
# 定义 LightGBM 参数
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'boosting_type': 'gbdt',
    'learning_rate': 0.05,
    'num_leaves': 100,
    'max_depth': -1,
    'min_data_in_leaf': 50,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'n_jobs': 4, 
    'seed': 42,
    'verbose': -1 # 减少日志输出
}

# %%
# K-Fold 交叉验证与预测
n_folds = 5
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)

# 用于存储每一次折叠对测试集的预测结果
test_preds = []
# 用于存储每一次折叠的验证分数
val_scores = []

print(f"Starting {n_folds}-Fold Cross-Validation...")

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y_log)):
    print(f"\n--- Fold {fold+1} ---")
    
    # 切分数据
    X_train_fold, y_train_fold = X.iloc[train_idx], y_log.iloc[train_idx]
    X_val_fold, y_val_fold = X.iloc[val_idx], y_log.iloc[val_idx]
    
    # 构建 Dataset
    train_data = lgb.Dataset(X_train_fold, label=y_train_fold)
    val_data = lgb.Dataset(X_val_fold, label=y_val_fold, reference=train_data)
    
    # 训练模型
    model = lgb.train(
        params,
        train_data,
        num_boost_round=5000,
        valid_sets=[train_data, val_data],
        callbacks=[
            lgb.early_stopping(stopping_rounds=100),
            lgb.log_evaluation(period=500)
        ]
    )
    
    # 记录最佳验证分数
    best_score = model.best_score['valid_1']['rmse']
    val_scores.append(best_score)
    print(f"Fold {fold+1} Best RMSE: {best_score}")
    
    # 对测试集进行预测 (Log scale)
    # 注意：这里预测的是 log(duration + 1)
    pred_log = model.predict(X_test, num_iteration=model.best_iteration)
    
    # 将预测结果还原为真实时长 (exp - 1) 并存入列表
    test_preds.append(np.expm1(pred_log))
# Out:
# Starting 5-Fold Cross-Validation...
#
# --- Fold 1 ---
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.374377	valid_1's rmse: 0.392893
# [1000]	training's rmse: 0.359313	valid_1's rmse: 0.390702
# [1500]	training's rmse: 0.349175	valid_1's rmse: 0.389658
# [2000]	training's rmse: 0.34132	valid_1's rmse: 0.389268
# [2500]	training's rmse: 0.334676	valid_1's rmse: 0.388761
# Early stopping, best iteration is:
# [2474]	training's rmse: 0.334987	valid_1's rmse: 0.388745
# Fold 1 Best RMSE: 0.38874518140688236
#
# --- Fold 2 ---
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.376287	valid_1's rmse: 0.386751
# [1000]	training's rmse: 0.361535	valid_1's rmse: 0.384284
# [1500]	training's rmse: 0.351436	valid_1's rmse: 0.383507
# Early stopping, best iteration is:
# [1873]	training's rmse: 0.345445	valid_1's rmse: 0.383015
# Fold 2 Best RMSE: 0.3830151416069402
#
# --- Fold 3 ---
# ...

# %%
# 计算平均预测结果
# axis=0 表示对 5 个模型的预测值按列取平均
final_pred = np.mean(test_preds, axis=0)

print("\n" + "="*30)
print(f"Average CV RMSE: {np.mean(val_scores)}")
print("="*30)
# Out:
# ...
# Average CV RMSE: 0.38743296903388913
# ...

# %%
# 绘制最后一个模型的特征重要性
lgb.plot_importance(model, max_num_features=15, importance_type='gain', figsize=(10,6))
plt.title("Feature Importance (Last Fold)")
plt.show()

# %%
# 生成提交文件
submission = pd.DataFrame({
    'id': df_test['id'],
    'trip_duration': final_pred
})
submission.to_csv('submission_kfold.csv', index=False)
print("Submission file saved to 'submission.csv'")
# Out:
# Submission file saved to 'submission_kfold.csv'
